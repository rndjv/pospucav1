# %% [markdown]
# <a href="https://colab.research.google.com/github/rndjv/pospucav1/blob/main/codigo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import date, timedelta

# %%
start_dt = date(2013, 10, 1)
end_dt = date(2013, 12, 31)

# diferença entre datas
delta = timedelta(days=1)

# salvar datas na lista
dates = []

while start_dt <= end_dt:
    # adicionando data e convertendo em iso format
    dates.append('https://raw.githubusercontent.com/rndjv/pospucav1/main/dataset/'+str(start_dt.isoformat())+'.csv')
    # incremetando a data pelo timedelta
    start_dt += delta

# %%
df = pd.DataFrame()
for arquivos in dates:
  #print(arquivos)
  #print(len(pd.read_csv(arquivos)))
  #print('-----------')
  df = pd.concat([df, pd.read_csv(arquivos)], ignore_index = True)

# %%
df.describe()
# Out:
#        capacity_bytes       failure  smart_1_normalized   smart_1_raw  \
# count    2.062043e+06  2.062043e+06                 0.0  2.062043e+06
# mean     2.886334e+12  1.571257e-04                 NaN  5.534137e+07
# std      8.717447e+11  1.253400e-02                 NaN  7.849762e+07
# min      1.000205e+12  0.000000e+00                 NaN  0.000000e+00
# 25%      2.000399e+12  0.000000e+00                 NaN  0.000000e+00
# 50%      3.000593e+12  0.000000e+00                 NaN  2.000000e+01
# 75%      4.000787e+12  0.000000e+00                 NaN  1.090546e+08
# max      4.000787e+12  1.000000e+00                 NaN  4.410211e+09
#
#        smart_2_normalized  smart_2_raw  smart_3_normalized  smart_3_raw  \
# count                 0.0          0.0                 0.0          0.0
# mean                  NaN          NaN                 NaN          NaN
# std                   NaN          NaN                 NaN          NaN
# min                   NaN          NaN                 NaN          NaN
# 25%                   NaN          NaN                 NaN          NaN
# 50%                   NaN          NaN                 NaN          NaN
# 75%                   NaN          NaN                 NaN          NaN
# max                   NaN          NaN                 NaN          NaN
#
#        smart_4_normalized  smart_4_raw  ...  smart_250_normalized  \
# count                 0.0          0.0  ...                   0.0
# mean                  NaN          NaN  ...                   NaN
# std                   NaN          NaN  ...                   NaN
# min                   NaN          NaN  ...                   NaN
# 25%                   NaN          NaN  ...                   NaN
# 50%                   NaN          NaN  ...                   NaN
# 75%                   NaN          NaN  ...                   NaN
# max                   NaN          NaN  ...                   NaN
#
#        smart_250_raw  smart_251_normalized  smart_251_raw  \
# count            0.0                   0.0            0.0
# mean             NaN                   NaN            NaN
# std              NaN                   NaN            NaN
# min              NaN                   NaN            NaN
# 25%              NaN                   NaN            NaN
# 50%              NaN                   NaN            NaN
# 75%              NaN                   NaN            NaN
# max              NaN                   NaN            NaN
#
#        smart_252_normalized  smart_252_raw  smart_254_normalized  \
# count                   0.0            0.0                   0.0
# mean                    NaN            NaN                   NaN
# std                     NaN            NaN                   NaN
# min                     NaN            NaN                   NaN
# 25%                     NaN            NaN                   NaN
# 50%                     NaN            NaN                   NaN
# 75%                     NaN            NaN                   NaN
# max                     NaN            NaN                   NaN
#
#        smart_254_raw  smart_255_normalized  smart_255_raw
# count            0.0                   0.0            0.0
# mean             NaN                   NaN            NaN
# std              NaN                   NaN            NaN
# min              NaN                   NaN            NaN
# 25%              NaN                   NaN            NaN
# 50%              NaN                   NaN            NaN
# 75%              NaN                   NaN            NaN
# max              NaN                   NaN            NaN
#
# [8 rows x 82 columns]

# %%
lista_colunas_normalizadas = []
for colunas in df.columns:
    if "normalized" in colunas:
        lista_colunas_normalizadas.append(colunas)
df = df.drop(columns = lista_colunas_normalizadas)

# %%
df.describe()
# Out:
#        capacity_bytes       failure   smart_1_raw  smart_2_raw  smart_3_raw  \
# count    2.062043e+06  2.062043e+06  2.062043e+06          0.0          0.0
# mean     2.886334e+12  1.571257e-04  5.534137e+07          NaN          NaN
# std      8.717447e+11  1.253400e-02  7.849762e+07          NaN          NaN
# min      1.000205e+12  0.000000e+00  0.000000e+00          NaN          NaN
# 25%      2.000399e+12  0.000000e+00  0.000000e+00          NaN          NaN
# 50%      3.000593e+12  0.000000e+00  2.000000e+01          NaN          NaN
# 75%      4.000787e+12  0.000000e+00  1.090546e+08          NaN          NaN
# max      4.000787e+12  1.000000e+00  4.410211e+09          NaN          NaN
#
#        smart_4_raw   smart_5_raw  smart_7_raw  smart_8_raw   smart_9_raw  ...  \
# count          0.0  2.062043e+06          0.0          0.0  2.062043e+06  ...
# mean           NaN  6.174800e+01          NaN          NaN  1.499052e+04  ...
# std            NaN  1.359881e+03          NaN          NaN  1.068246e+04  ...
# min            NaN  0.000000e+00          NaN          NaN  1.000000e+00  ...
# 25%            NaN  0.000000e+00          NaN          NaN  6.331000e+03  ...
# 50%            NaN  0.000000e+00          NaN          NaN  1.332700e+04  ...
# 75%            NaN  0.000000e+00          NaN          NaN  2.284000e+04  ...
# max            NaN  6.538400e+04          NaN          NaN  2.604250e+05  ...
#
#        smart_223_raw  smart_225_raw  smart_240_raw  smart_241_raw  \
# count            0.0            0.0            0.0            0.0
# mean             NaN            NaN            NaN            NaN
# std              NaN            NaN            NaN            NaN
# min              NaN            NaN            NaN            NaN
# 25%              NaN            NaN            NaN            NaN
# 50%              NaN            NaN            NaN            NaN
# 75%              NaN            NaN            NaN            NaN
# max              NaN            NaN            NaN            NaN
#
#        smart_242_raw  smart_250_raw  smart_251_raw  smart_252_raw  \
# count            0.0            0.0            0.0            0.0
# mean             NaN            NaN            NaN            NaN
# std              NaN            NaN            NaN            NaN
# min              NaN            NaN            NaN            NaN
# 25%              NaN            NaN            NaN            NaN
# 50%              NaN            NaN            NaN            NaN
# 75%              NaN            NaN            NaN            NaN
# max              NaN            NaN            NaN            NaN
#
#        smart_254_raw  smart_255_raw
# count            0.0            0.0
# mean             NaN            NaN
# std              NaN            NaN
# min              NaN            NaN
# 25%              NaN            NaN
# 50%              NaN            NaN
# 75%              NaN            NaN
# max              NaN            NaN
#
# [8 rows x 42 columns]
